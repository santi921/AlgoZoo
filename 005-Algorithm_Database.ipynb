# %%
import pandas as pd
# !ls
# Out:
#  001-Thresholding.ipynb		       LICENSE
#  002-BasicNN.ipynb		       ML_Helpers.py
# '002-Linear Regressor.ipynb'	      'ML_Helpers.py~Stashed changes'
#  003-ImageStandardizationAndDb.ipynb   ML_Methods.py
#  004-SegmentationMap.ipynb	       Predictor.py
#  005-Algorithm_Database.ipynb	       Processor.py
#  Algorithm_DB			       __pycache__
#  images				       README.md
#  Image_Tools			       StandardizedImages
#  Image_Tools.py

# %%
#DB Structure:
# name|||||test acc|||||train acc|||||f1m train|||||f1m test|||||dataset #////k-folds ff scikit

df = pd.DataFrame(columns=['ref','type' ,'train_acc', 'test_acc', 'f1m_train', 'f1m_test', 'kfolds', 'dataset', 'parameters','aug', 'train_time', 'imsize'])
test = {'train_acc':[0], 'test_acc':[0], 'f1m_train':[0], 'f1m_test':[0], 'kfolds':[0], 'dataset':[0],'parameters':[[0,1,2,2,3]] }

# %%
test = pd.DataFrame.from_dict(test)

# %%
test
# Out:
#    dataset  f1m_test  f1m_train  kfolds       parameters  test_acc  train_acc
# 0        0         0          0       0  [0, 1, 2, 2, 3]         0          0

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.append(test)
# Out:
# /home/santiagovargas/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#   dataset f1m_test f1m_train kfolds       parameters  ref test_acc train_acc  \
# 0       0        0         0      0  [0, 1, 2, 2, 3]  NaN        0         0
#
#   type
# 0  NaN

# %%
df.to_pickle("./Algorithm_DB/***statistics_DONTDELETE.pkl")

# %%
df = pd.read_pickle("./Algorithm_DB/***statistics_DONTDELETE.pkl")

# %%
df
# Out:
#      aug dataset  f1m_test  f1m_train imsize    kfolds  \
# 0  False       3  0.625344   0.601292    256  0.645698
# 0  False       3  0.552326   0.579480    512  0.700559
# 0  False       3  0.250000   0.294643   1024  0.969697
# 0  False       3  0.590620   0.595442    128  0.793893
# 0  False       3  0.779837   0.776294     64  0.753995
# 0  False       3  0.625169   0.623367     64  0.770908
# 0  False       3  0.547243   0.544998     64  0.775011
# 0  False       3  0.592055   0.580856     64  0.718059
# 0  False       3  0.620408   0.604478    256  0.600120
# 0  False       3  0.601093   0.625645    256  0.654597
# 0  False       3  0.615032   0.623790    128  0.792758
# 0  False       3  0.735367   0.739343    128  0.844202
# 0  False       3  0.627444   0.614518    128  0.817513
# 0  False       3  0.597748   0.585461    128  0.849344
# 0  False       3  0.590511   0.598404    128  0.846607
# 0  False       3  0.597833   0.601368    128  0.845874
# 0  False       3       NaN        NaN    NaN       NaN
# 0  False       3       NaN        NaN    NaN       NaN
#
#                                           parameters  \
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                           [log, 1e-09, 100, 1e-08]
# 0                        [hinge, 1e-09, 1000, 1e-08]
# 0                 [squared_loss, 1e-09, 1000, 1e-08]
# 0                   [preceptron, 1e-09, 1000, 1e-08]
# 0  [hinge, 3.73512173637078e-05, 62630.2239746851...
# 0  [squared_loss, 1.5513554765033017e-08, 1476.26...
# 0  [preceptron, 2.327487732594701e-05, 746635.160...
# 0  [squared_loss, 1.0359060519572734e-06, 3834.34...
# 0  [preceptron, 1.3265088815454246e-07, 25059.538...
# 0  [hinge, 2.205723934476629e-07, 264111.88046905...
# 0                               [10, 10, [182, 1.2]]
# 0                                [10, 10, [89, 0.6]]
#
#                                        ref  test_acc  train_acc   train_len  \
# 0  Algorithm_DB/sgd_2019-7-19-15-42-16.pkl  0.978437   0.992243         NaN
# 0    Algorithm_DB/sgd_2019-7-19-16-0-3.pkl  0.988506   1.000000         NaN
# 0   Algorithm_DB/sgd_2019-7-19-16-1-38.pkl  1.000000   1.000000         NaN
# 0    Algorithm_DB/sgd_2019-7-19-16-8-9.pkl  0.995996   0.995662         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-12-28.pkl  0.735006   0.729601         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-19-58.pkl  0.858781   0.860148         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-24-18.pkl  0.857202   0.855912         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-36-32.pkl  0.876225   0.872651         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-47-38.pkl  0.990566   0.994266         NaN
# 0  Algorithm_DB/sgd_2019-7-19-16-51-49.pkl  0.986523   0.981113         NaN
# 0   Algorithm_DB/sgd_2019-7-22-0-51-17.pkl  0.945612   0.948273         NaN
# 0   Algorithm_DB/sgd_2019-7-22-0-52-16.pkl  0.809476   0.802436         NaN
# 0   Algorithm_DB/sgd_2019-7-22-0-55-17.pkl  0.955622   0.955114         NaN
# 0  Algorithm_DB/sgd_2019-7-22-16-43-45.pkl  0.977978   0.980144         NaN
# 0  Algorithm_DB/sgd_2019-7-22-16-46-17.pkl  0.991658   0.993242         NaN
# 0  Algorithm_DB/sgd_2019-7-22-16-48-42.pkl  0.985652   0.988069         NaN
# 0    AlgorithmDB/nn_2019-7-23-14-47-50.pkl       NaN        NaN  331.042516
# 0    AlgorithmDB/nn_2019-7-23-14-50-23.pkl       NaN        NaN  151.589828
#
#    train_time type
# 0   10.423782  sgd
# 0    9.970518  sgd
# 0    1.289669  sgd
# 0   11.153292  sgd
# 0   31.320685  sgd
# 0   34.165128  sgd
# 0   36.514073  sgd
# 0   30.405345  sgd
# 0   14.699657  sgd
# 0   13.147713  sgd
# 0   27.540414  sgd
# 0    9.281668  sgd
# 0   25.183903  sgd
# 0   35.159068  sgd
# 0   19.813161  sgd
# 0   18.795438  sgd
# 0         NaN   nn
# 0         NaN   nn
